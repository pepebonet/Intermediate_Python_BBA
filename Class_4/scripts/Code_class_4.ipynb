# %% [markdown]
# # Class 5. Intermediate Python & AI

# %% [markdown]
# # Numerical EDA & Feature Engineering

# %% [markdown]
# ### Table of contents
#
# 1. Numerical EDA (Class 4 Code)
#     1. Univariate analysis
#     2. Bivariate analysis (Categorical + Numerical)
#     3. Multivariate analysis
# 2. Feature Engineering

# %%
import pandas as pd

# %%
df = pd.read_csv('../../datasets/exams_mod_cleaned.csv')

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1    male        group E                some college  free/reduced
# 2    male        group B                 high school      standard
# 3    male        group E          associate's degree      standard
# 4  female        group D                 high school      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0               completed          67             67             63
# 1                    none          59             60             50
# 2                    none          77             78             68
# 3               completed          78             73             68
# 4                    none          63             77             76
#
#    id_student  Year   Age
# 0        1000  2022  17.0
# 1        1002  2022  17.0
# 2        1003  2022  17.0
# 3        1004  2022  17.0
# 4        1005  2022  17.0

# %% [markdown]
# ## 2. Feature Engineering

# %% [markdown]
# ### Parental Education

# %%
df['parental level of education'].value_counts()
# Out:
# some college          219
# associate's degree    196
# high school           194
# some high school      180
# bachelor's degree     107
# master's degree        67
# Name: parental level of education, dtype: int64

# %%
new_col = []
for el in df['parental level of education'].tolist():
    if el in ["master's degree", "bachelor's degree", "some college"]:
        new_col.append('went to college')
    else:
        new_col.append('no college')
df['Education'] = new_col

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1    male        group E                some college  free/reduced
# 2    male        group B                 high school      standard
# 3    male        group E          associate's degree      standard
# 4  female        group D                 high school      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0               completed          67             67             63
# 1                    none          59             60             50
# 2                    none          77             78             68
# 3               completed          78             73             68
# 4                    none          63             77             76
#
#    id_student  Year   Age        Education
# 0        1000  2022  17.0       no college
# 1        1002  2022  17.0  went to college
# 2        1003  2022  17.0       no college
# 3        1004  2022  17.0       no college
# 4        1005  2022  17.0       no college

# %%
df['Education'].value_counts()
# Out:
# no college         570
# went to college    393
# Name: Education, dtype: int64

# %% [markdown]
# ### BMI Calculation

# %%
df['height'] = 1.70
df['weight'] = 70

# %%
df['BMI'] =  round(df['weight'] / (df['height'] * df['height']), 2)

# %%
df.drop(['height', 'weight'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1    male        group E                some college  free/reduced
# 2    male        group B                 high school      standard
# 3    male        group E          associate's degree      standard
# 4  female        group D                 high school      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0               completed          67             67             63
# 1                    none          59             60             50
# 2                    none          77             78             68
# 3               completed          78             73             68
# 4                    none          63             77             76
#
#    id_student  Year   Age        Education  exams mean    BMI
# 0        1000  2022  17.0       no college       65.67  24.22
# 1        1002  2022  17.0  went to college       56.33  24.22
# 2        1003  2022  17.0       no college       74.33  24.22
# 3        1004  2022  17.0       no college       73.00  24.22
# 4        1005  2022  17.0       no college       72.00  24.22

# %% [markdown]
# ### Scores mean

# %%
df['exams mean'] = round((df['reading score'] + df['math score'] + df['writing score']) / 3, 2)

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1    male        group E                some college  free/reduced
# 2    male        group B                 high school      standard
# 3    male        group E          associate's degree      standard
# 4  female        group D                 high school      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0               completed          67             67             63
# 1                    none          59             60             50
# 2                    none          77             78             68
# 3               completed          78             73             68
# 4                    none          63             77             76
#
#    id_student  Year   Age        Education  exams mean
# 0        1000  2022  17.0       no college       65.67
# 1        1002  2022  17.0  went to college       56.33
# 2        1003  2022  17.0       no college       74.33
# 3        1004  2022  17.0       no college       73.00
# 4        1005  2022  17.0       no college       72.00
