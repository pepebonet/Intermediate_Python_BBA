# %% [markdown]
# # Class 4. Intermediate Python & AI

# %% [markdown]
# # Numerical EDA & Feature Engineering

# %% [markdown]
# ### Table of contents
#
# 1. Numerical EDA (Class 4 Code)
#     1. Univariate analysis
#     2. Bivariate analysis (Categorical + Numerical)
#     3. Multivariate analysis
# 2. Feature Engineering

# %%
import pandas as pd

# %%
df = pd.read_csv('../../datasets/exams_mod_cleaned.csv')

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1    male        group E                some college  free/reduced
# 2    male        group B                 high school      standard
# 3    male        group E          associate's degree      standard
# 4  female        group D                 high school      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0               completed          67             67             63
# 1                    none          59             60             50
# 2                    none          77             78             68
# 3               completed          78             73             68
# 4                    none          63             77             76
#
#    id_student  Year   Age
# 0        1000  2022  17.0
# 1        1002  2022  17.0
# 2        1003  2022  17.0
# 3        1004  2022  17.0
# 4        1005  2022  17.0

# %%
df.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# id_student                     0
# Year                           0
# Age                            0
# dtype: int64

# %%
df['gender'].value_counts()
# Out:
# male      497
# female    466
# Name: gender, dtype: int64

# %% [markdown]
# ## 2. Feature Engineering

# %% [markdown]
# ### Parental Education

# %%
df['parental level of education'].value_counts()
# Out:
# some college          219
# associate's degree    196
# high school           194
# some high school      180
# bachelor's degree     107
# master's degree        67
# Name: parental level of education, dtype: int64

# %%
new_col = []
for el in df['parental level of education'].tolist():
    if el in ["master's degree", "bachelor's degree", "some college"]:
        new_col.append('went to college')
    else:
        new_col.append('no college')
df['Education'] = new_col

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1    male        group E                some college  free/reduced
# 2    male        group B                 high school      standard
# 3    male        group E          associate's degree      standard
# 4  female        group D                 high school      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0               completed          67             67             63
# 1                    none          59             60             50
# 2                    none          77             78             68
# 3               completed          78             73             68
# 4                    none          63             77             76
#
#    id_student  Year   Age        Education
# 0        1000  2022  17.0       no college
# 1        1002  2022  17.0  went to college
# 2        1003  2022  17.0       no college
# 3        1004  2022  17.0       no college
# 4        1005  2022  17.0       no college

# %%
df['Education'].value_counts()
# Out:
# no college         570
# went to college    393
# Name: Education, dtype: int64

# %% [markdown]
# ### BMI Calculation

# %%
df['height'] = 1.70
df['weight'] = 70

# %%
df['BMI'] =  round(df['weight'] / (df['height'] * df['height']), 2)

# %%
df.drop(['height', 'weight'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1    male        group E                some college  free/reduced
# 2    male        group B                 high school      standard
# 3    male        group E          associate's degree      standard
# 4  female        group D                 high school      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0               completed          67             67             63
# 1                    none          59             60             50
# 2                    none          77             78             68
# 3               completed          78             73             68
# 4                    none          63             77             76
#
#    id_student  Year   Age        Education    BMI
# 0        1000  2022  17.0       no college  24.22
# 1        1002  2022  17.0  went to college  24.22
# 2        1003  2022  17.0       no college  24.22
# 3        1004  2022  17.0       no college  24.22
# 4        1005  2022  17.0       no college  24.22

# %% [markdown]
# ### Scores mean

# %%
df['exams mean'] = round((df['reading score'] + df['math score'] + df['writing score']) / 3, 2)

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1    male        group E                some college  free/reduced
# 2    male        group B                 high school      standard
# 3    male        group E          associate's degree      standard
# 4  female        group D                 high school      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0               completed          67             67             63
# 1                    none          59             60             50
# 2                    none          77             78             68
# 3               completed          78             73             68
# 4                    none          63             77             76
#
#    id_student  Year   Age        Education    BMI  exams mean
# 0        1000  2022  17.0       no college  24.22       65.67
# 1        1002  2022  17.0  went to college  24.22       56.33
# 2        1003  2022  17.0       no college  24.22       74.33
# 3        1004  2022  17.0       no college  24.22       73.00
# 4        1005  2022  17.0       no college  24.22       72.00

# %% [markdown]
# # Categorical Encoding

# %%
df["parent_ed_cat_encode"] = df["parental level of education"]\
    .astype('category').cat.codes

# %%
df[['parental level of education', 'parent_ed_cat_encode']].head()
# Out:
#   parental level of education  parent_ed_cat_encode
# 0                 high school                     2
# 1                some college                     4
# 2                 high school                     2
# 3          associate's degree                     0
# 4                 high school                     2

# %% [markdown]
# #### You can also do it with scikit learn

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()
le.fit(df['parental level of education'])
df["parent_ed_cat_encode_2"] = le.transform(df['parental level of education'])

# %%
assert df["parent_ed_cat_encode"].all() == df["parent_ed_cat_encode_2"].all()

# %% [markdown]
# # One hot Encoding

# %%
pd.get_dummies(df['gender'], columns=['gender']).head()
# Out:
#    female  male
# 0       0     1
# 1       0     1
# 2       0     1
# 3       0     1
# 4       1     0

# %%
data = pd.get_dummies(
        df, columns=['gender', 'race/ethnicity', 
     'parental level of education', 'lunch', 'test preparation course'], 
drop_first=True)
data.head()
# Out:
#    math score  reading score  writing score  id_student  Year   Age  \
# 0          67             67             63        1000  2022  17.0
# 1          59             60             50        1002  2022  17.0
# 2          77             78             68        1003  2022  17.0
# 3          78             73             68        1004  2022  17.0
# 4          63             77             76        1005  2022  17.0
#
#          Education    BMI  exams mean  parent_ed_cat_encode  ...  \
# 0       no college  24.22       65.67                     2  ...
# 1  went to college  24.22       56.33                     4  ...
# 2       no college  24.22       74.33                     2  ...
# 3       no college  24.22       73.00                     0  ...
# 4       no college  24.22       72.00                     2  ...
#
#    race/ethnicity_group C  race/ethnicity_group D  race/ethnicity_group E  \
# 0                       0                       0                       0
# 1                       0                       0                       1
# 2                       0                       0                       0
# 3                       0                       0                       1
# 4                       0                       1                       0
#
#    parental level of education_bachelor's degree  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
#
#    parental level of education_high school  \
# 0                                        1
# 1                                        0
# 2                                        1
# 3                                        0
# 4                                        1
#
#    parental level of education_master's degree  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#    parental level of education_some college  \
# 0                                         0
# 1                                         1
# 2                                         0
# 3                                         0
# 4                                         0
#
#    parental level of education_some high school  lunch_standard  \
# 0                                             0               1
# 1                                             0               0
# 2                                             0               1
# 3                                             0               1
# 4                                             0               1
#
#    test preparation course_none
# 0                             0
# 1                             1
# 2                             1
# 3                             0
# 4                             1
#
# [5 rows x 23 columns]

# %% [markdown]
# # Data Normalization

# %%
scaler = preprocessing.MinMaxScaler()

# %%
df[['norm_math', 'norm_read']] = scaler.fit_transform(df[['math score', 'reading score']])

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group A                 high school      standard
# 1    male        group E                some college  free/reduced
# 2    male        group B                 high school      standard
# 3    male        group E          associate's degree      standard
# 4  female        group D                 high school      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0               completed          67             67             63
# 1                    none          59             60             50
# 2                    none          77             78             68
# 3               completed          78             73             68
# 4                    none          63             77             76
#
#    id_student  Year   Age        Education    BMI  exams mean  \
# 0        1000  2022  17.0       no college  24.22       65.67
# 1        1002  2022  17.0  went to college  24.22       56.33
# 2        1003  2022  17.0       no college  24.22       74.33
# 3        1004  2022  17.0       no college  24.22       73.00
# 4        1005  2022  17.0       no college  24.22       72.00
#
#    parent_ed_cat_encode  parent_ed_cat_encode_2  norm_math  norm_read
# 0                     2                       2   0.620690   0.547945
# 1                     4                       4   0.528736   0.452055
# 2                     2                       2   0.735632   0.698630
# 3                     0                       0   0.747126   0.630137
# 4                     2                       2   0.574713   0.684932

# %%
data = [[10], [25], [53], [42]]
scaler = preprocessing.MinMaxScaler()
scaler.fit_transform(data)
# Out:
# array([[0.        ],
#        [0.34883721],
#        [1.        ],
#        [0.74418605]])
